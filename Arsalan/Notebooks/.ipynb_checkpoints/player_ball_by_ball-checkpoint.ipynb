# %% [markdown]
# # Player Ball By Ball data
#
# ### Making the final input.
#
# Using all the dataframes we have already worked on, we are going to use them now to implement the final input.
#
# **Inputs:**
# - Player Bowling and Batting Stats
# - Player

# %%
import numpy as np
import pandas as pd

# %%
# Loading all the player stats data form disk
bowlingStats = pd.read_csv("playerData/bowling.csv")
battingStats = pd.read_csv("playerData/batting.csv")
bowlingStats.set_index("S. no")
battingStats.set_index("S. no")

# loading the match data from the disk
innings = pd.read_csv("match_data.csv")
innings.set_index(["Match Code", "Country", "Over", "Ball"], inplace = True)
innings
# Out:
# C:\Users\HOME\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (15,16) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                                             batter         bowler  \
# Match Code Country     Over Ball
# 1381452    Austria     0    0     M Simpson-Parker  Ghulam Ahmadi
#                             1     M Simpson-Parker  Ghulam Ahmadi
#                             2     M Simpson-Parker  Ghulam Ahmadi
#                             3     M Simpson-Parker  Ghulam Ahmadi
#                             4     M Simpson-Parker  Ghulam Ahmadi
# ...                                            ...            ...
# 211048     New Zealand 19   1            JW Wilson     GD McGrath
#                             2            JW Wilson     GD McGrath
#                             3            DR Tuffey     GD McGrath
# ...

# %%
innings.to_csv("match_data.csv")
