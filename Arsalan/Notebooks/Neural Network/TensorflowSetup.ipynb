# %%
conda uninstall tensorflow
# Out:
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... failed
#
# Note: you may need to restart the kernel to use updated packages.
# PackagesNotFoundError: The following packages are missing from the target environment:
#   - tensorflow

# %%
conda install tensorflow
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: ...working... failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\HOME\anaconda3
#
#   added / updated specs:
#     - tensorflow
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _anaconda_depends-2020.07  |           py38_0           6 KB
#     _tflow_select-2.3.0        |            eigen           4 KB
#     absl-py-1.4.0              |   py38haa95532_0         180 KB
#     aiohttp-3.8.3              |   py38h2bbff1b_0         416 KB
#     aiosignal-1.2.0            |     pyhd3eb1b0_0          12 KB
#     anaconda-custom            |           py38_2          13 KB
#     astor-0.8.1                |   py38haa95532_0          47 KB
#     astunparse-1.6.3           |             py_0          17 KB
#     async-timeout-4.0.2        |   py38haa95532_0          12 KB
#     blinker-1.4                |   py38haa95532_0          23 KB
#     cachetools-4.2.2           |     pyhd3eb1b0_0          13 KB
#     certifi-2023.7.22          |   py38haa95532_0         154 KB
#     conda-4.12.0               |   py38haa95532_0        14.5 MB
#     frozenlist-1.3.3           |   py38h2bbff1b_0          40 KB
#     gast-0.4.0                 |     pyhd3eb1b0_0          13 KB
#     gmpy2-2.1.2                |   py38h7f96b67_0         160 KB
#     google-auth-2.6.0          |     pyhd3eb1b0_0          83 KB
#     google-auth-oauthlib-0.4.4 |     pyhd3eb1b0_0          18 KB
#     google-pasta-0.2.0         |     pyhd3eb1b0_0          46 KB
#     grpcio-1.42.0              |   py38hc60d5dd_0         1.9 MB
#     keras-applications-1.0.8   |             py_1          29 KB
#     keras-preprocessing-1.1.2  |     pyhd3eb1b0_0          35 KB
#     libllvm9-9.0.1             |       h21ff451_0          61 KB
#     libprotobuf-3.19.1         |       h23ce68f_0         1.9 MB
#     markdown-3.3.4             |   py38haa95532_0         144 KB
#     mpc-1.1.0                  |       h7edee0f_1         260 KB
#     mpfr-4.0.2                 |       h62dcd97_1         1.5 MB
#     mpir-3.0.0                 |       hec2e145_1         1.3 MB
#     multidict-6.0.2            |   py38h2bbff1b_0          46 KB
#     oauthlib-3.2.2             |   py38haa95532_0         209 KB
#     openssl-1.1.1v             |       h2bbff1b_0         5.5 MB
#     opt_einsum-3.3.0           |     pyhd3eb1b0_1          57 KB
#     pathtools-0.1.2            |     pyhd3eb1b0_1           9 KB
#     protobuf-3.19.1            |   py38hd77b12b_0         239 KB
#     pyasn1-0.4.8               |     pyhd3eb1b0_0          54 KB
#     pyasn1-modules-0.2.8       |             py_0          72 KB
#     requests-oauthlib-1.3.0    |             py_0          23 KB
#     rsa-4.7.2                  |     pyhd3eb1b0_1          28 KB
#     tensorboard-2.10.0         |   py38haa95532_0         5.6 MB
#     tensorboard-data-server-0.6.1|   py38haa95532_0          17 KB
#     tensorboard-plugin-wit-1.8.1|   py38haa95532_0         671 KB
#     tensorflow-2.3.0           |mkl_py38h8c0d9a2_0           6 KB
#     tensorflow-base-2.3.0      |eigen_py38h75a453f_0        49.5 MB
#     tensorflow-estimator-2.6.0 |     pyh7b7c402_0         267 KB
#     termcolor-2.1.0            |   py38haa95532_0          12 KB
#     yarl-1.8.1                 |   py38h2bbff1b_0          80 KB
#     ------------------------------------------------------------
#                                            Total:        85.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   _anaconda_depends  pkgs/main/win-64::_anaconda_depends-2020.07-py38_0
#   _tflow_select      pkgs/main/win-64::_tflow_select-2.3.0-eigen
#   absl-py            pkgs/main/win-64::absl-py-1.4.0-py38haa95532_0
#   aiohttp            pkgs/main/win-64::aiohttp-3.8.3-py38h2bbff1b_0
#   aiosignal          pkgs/main/noarch::aiosignal-1.2.0-pyhd3eb1b0_0
#   astor              pkgs/main/win-64::astor-0.8.1-py38haa95532_0
#   astunparse         pkgs/main/noarch::astunparse-1.6.3-py_0
#   async-timeout      pkgs/main/win-64::async-timeout-4.0.2-py38haa95532_0
#   blinker            pkgs/main/win-64::blinker-1.4-py38haa95532_0
#   cachetools         pkgs/main/noarch::cachetools-4.2.2-pyhd3eb1b0_0
#   charset-normalizer pkgs/main/noarch::charset-normalizer-2.0.4-pyhd3eb1b0_0
#   frozenlist         pkgs/main/win-64::frozenlist-1.3.3-py38h2bbff1b_0
#   gast               pkgs/main/noarch::gast-0.4.0-pyhd3eb1b0_0
#   gmpy2              pkgs/main/win-64::gmpy2-2.1.2-py38h7f96b67_0
#   google-auth        pkgs/main/noarch::google-auth-2.6.0-pyhd3eb1b0_0
#   google-auth-oauth~ pkgs/main/noarch::google-auth-oauthlib-0.4.4-pyhd3eb1b0_0
#   google-pasta       pkgs/main/noarch::google-pasta-0.2.0-pyhd3eb1b0_0
#   grpcio             pkgs/main/win-64::grpcio-1.42.0-py38hc60d5dd_0
#   importlib-metadata pkgs/main/win-64::importlib-metadata-3.10.0-py38haa95532_0
#   keras-applications pkgs/main/noarch::keras-applications-1.0.8-py_1
#   keras-preprocessi~ pkgs/main/noarch::keras-preprocessing-1.1.2-pyhd3eb1b0_0
#   libllvm9           pkgs/main/win-64::libllvm9-9.0.1-h21ff451_0
#   libprotobuf        pkgs/main/win-64::libprotobuf-3.19.1-h23ce68f_0
#   markdown           pkgs/main/win-64::markdown-3.3.4-py38haa95532_0
#   mpc                pkgs/main/win-64::mpc-1.1.0-h7edee0f_1
#   mpfr               pkgs/main/win-64::mpfr-4.0.2-h62dcd97_1
#   mpir               pkgs/main/win-64::mpir-3.0.0-hec2e145_1
#   multidict          pkgs/main/win-64::multidict-6.0.2-py38h2bbff1b_0
#   numpy-base         pkgs/main/win-64::numpy-base-1.20.1-py38haf7ebc8_0
#   oauthlib           pkgs/main/win-64::oauthlib-3.2.2-py38haa95532_0
#   opt_einsum         pkgs/main/noarch::opt_einsum-3.3.0-pyhd3eb1b0_1
#   pathtools          pkgs/main/noarch::pathtools-0.1.2-pyhd3eb1b0_1
#   protobuf           pkgs/main/win-64::protobuf-3.19.1-py38hd77b12b_0
#   pyasn1             pkgs/main/noarch::pyasn1-0.4.8-pyhd3eb1b0_0
#   pyasn1-modules     pkgs/main/noarch::pyasn1-modules-0.2.8-py_0
#   requests-oauthlib  pkgs/main/noarch::requests-oauthlib-1.3.0-py_0
#   rsa                pkgs/main/noarch::rsa-4.7.2-pyhd3eb1b0_1
#   tensorboard        pkgs/main/win-64::tensorboard-2.10.0-py38haa95532_0
#   tensorboard-data-~ pkgs/main/win-64::tensorboard-data-server-0.6.1-py38haa95532_0
#   tensorboard-plugi~ pkgs/main/win-64::tensorboard-plugin-wit-1.8.1-py38haa95532_0
#   tensorflow         pkgs/main/win-64::tensorflow-2.3.0-mkl_py38h8c0d9a2_0
#   tensorflow-base    pkgs/main/win-64::tensorflow-base-2.3.0-eigen_py38h75a453f_0
#   tensorflow-estima~ pkgs/main/noarch::tensorflow-estimator-2.6.0-pyh7b7c402_0
#   termcolor          pkgs/main/win-64::termcolor-2.1.0-py38haa95532_0
#   yarl               pkgs/main/win-64::yarl-1.8.1-py38h2bbff1b_0
#
# The following packages will be UPDATED:
#
#   ca-certificates                      2021.4.13-haa95532_1 --> 2023.05.30-haa95532_0
#   certifi                          2020.12.5-py38haa95532_0 --> 2023.7.22-py38haa95532_0
#   conda                               4.10.1-py38haa95532_1 --> 4.12.0-py38haa95532_0
#   openssl                                 1.1.1k-h2bbff1b_0 --> 1.1.1v-h2bbff1b_0
#
# The following packages will be DOWNGRADED:
#
#   anaconda                                   2021.05-py38_0 --> custom-py38_2
#
#
#
# Downloading and Extracting Packages
#
# mpfr-4.0.2           | 1.5 MB    |            |   0%
# mpfr-4.0.2           | 1.5 MB    | 1          |   1%
# mpfr-4.0.2           | 1.5 MB    | #          |  10%
# mpfr-4.0.2           | 1.5 MB    | #6         |  16%
# mpfr-4.0.2           | 1.5 MB    | ##7        |  28%
# mpfr-4.0.2           | 1.5 MB    | ###3       |  34%
# mpfr-4.0.2           | 1.5 MB    | ####5      |  45%
# mpfr-4.0.2           | 1.5 MB    | #####6     |  57%
# mpfr-4.0.2           | 1.5 MB    | ######5    |  66%
# mpfr-4.0.2           | 1.5 MB    | #######6   |  76%
# mpfr-4.0.2           | 1.5 MB    | #########  |  90%
# mpfr-4.0.2           | 1.5 MB    | ########## | 100%
#
# _tflow_select-2.3.0  | 4 KB      |            |   0%
# _tflow_select-2.3.0  | 4 KB      | ########## | 100%
# _tflow_select-2.3.0  | 4 KB      | ########## | 100%
#
# protobuf-3.19.1      | 239 KB    |            |   0%
# protobuf-3.19.1      | 239 KB    | 6          |   7%
# protobuf-3.19.1      | 239 KB    | ######7    |  67%
# protobuf-3.19.1      | 239 KB    | ########## | 100%
#
# astunparse-1.6.3     | 17 KB     |            |   0%
# astunparse-1.6.3     | 17 KB     | #########5 |  95%
# astunparse-1.6.3     | 17 KB     | ########## | 100%
#
# astor-0.8.1          | 47 KB     |            |   0%
# astor-0.8.1          | 47 KB     | ###3       |  34%
# astor-0.8.1          | 47 KB     | ########## | 100%
#
# google-auth-oauthlib | 18 KB     |            |   0%
# google-auth-oauthlib | 18 KB     | ########7  |  87%
# google-auth-oauthlib | 18 KB     | ########## | 100%
#
# pyasn1-0.4.8         | 54 KB     |            |   0%
# pyasn1-0.4.8         | 54 KB     | ##9        |  30%
# pyasn1-0.4.8         | 54 KB     | ########## | 100%
#
# markdown-3.3.4       | 144 KB    |            |   0%
# markdown-3.3.4       | 144 KB    | #1         |  11%
# markdown-3.3.4       | 144 KB    | ########## | 100%
# markdown-3.3.4       | 144 KB    | ########## | 100%
#
# gmpy2-2.1.2          | 160 KB    |            |   0%
# gmpy2-2.1.2          | 160 KB    | #          |  10%
# gmpy2-2.1.2          | 160 KB    | ########## | 100%
#
# google-auth-2.6.0    | 83 KB     |            |   0%
# google-auth-2.6.0    | 83 KB     | #####8     |  58%
# google-auth-2.6.0    | 83 KB     | ########## | 100%
#
# tensorboard-data-ser | 17 KB     |            |   0%
# tensorboard-data-ser | 17 KB     | #########6 |  96%
# tensorboard-data-ser | 17 KB     | ########## | 100%
#
# google-pasta-0.2.0   | 46 KB     |            |   0%
# google-pasta-0.2.0   | 46 KB     | ########## | 100%
# google-pasta-0.2.0   | 46 KB     | ########## | 100%
#
# opt_einsum-3.3.0     | 57 KB     |            |   0%
# opt_einsum-3.3.0     | 57 KB     | ##7        |  28%
# opt_einsum-3.3.0     | 57 KB     | ########## | 100%
#
# tensorflow-estimator | 267 KB    |            |   0%
# tensorflow-estimator | 267 KB    | 5          |   6%
# tensorflow-estimator | 267 KB    | ########## | 100%
# tensorflow-estimator | 267 KB    | ########## | 100%
#
# conda-4.12.0         | 14.5 MB   |            |   0%
# conda-4.12.0         | 14.5 MB   |            |   0%
# conda-4.12.0         | 14.5 MB   | 3          |   3%
# conda-4.12.0         | 14.5 MB   | 6          |   6%
# conda-4.12.0         | 14.5 MB   | 8          |   9%
# conda-4.12.0         | 14.5 MB   | #1         |  12%
# conda-4.12.0         | 14.5 MB   | #4         |  15%
# conda-4.12.0         | 14.5 MB   | #7         |  18%
# conda-4.12.0         | 14.5 MB   | ##         |  21%
# conda-4.12.0         | 14.5 MB   | ##3        |  23%
# conda-4.12.0         | 14.5 MB   | ##6        |  26%
# conda-4.12.0         | 14.5 MB   | ##9        |  29%
# conda-4.12.0         | 14.5 MB   | ###2       |  32%
# conda-4.12.0         | 14.5 MB   | ###5       |  35%
# conda-4.12.0         | 14.5 MB   | ###7       |  38%
# conda-4.12.0         | 14.5 MB   | ####       |  41%
# conda-4.12.0         | 14.5 MB   | ####3      |  44%
# conda-4.12.0         | 14.5 MB   | ####6      |  47%
# conda-4.12.0         | 14.5 MB   | ####9      |  50%
# conda-4.12.0         | 14.5 MB   | #####2     |  52%
# conda-4.12.0         | 14.5 MB   | #####5     |  55%
# conda-4.12.0         | 14.5 MB   | #####8     |  58%
# conda-4.12.0         | 14.5 MB   | ######1    |  61%
# conda-4.12.0         | 14.5 MB   | ######4    |  64%
# conda-4.12.0         | 14.5 MB   | ######7    |  67%
# conda-4.12.0         | 14.5 MB   | ######9    |  70%
# conda-4.12.0         | 14.5 MB   | #######2   |  73%
# conda-4.12.0         | 14.5 MB   | #######5   |  76%
# conda-4.12.0         | 14.5 MB   | #######8   |  79%
# conda-4.12.0         | 14.5 MB   | ########1  |  82%
# conda-4.12.0         | 14.5 MB   | ########4  |  85%
# conda-4.12.0         | 14.5 MB   | ########7  |  88%
# conda-4.12.0         | 14.5 MB   | #########  |  91%
# conda-4.12.0         | 14.5 MB   | #########3 |  94%
# conda-4.12.0         | 14.5 MB   | #########6 |  96%
# conda-4.12.0         | 14.5 MB   | #########9 |  99%
# conda-4.12.0         | 14.5 MB   | ########## | 100%
#
# frozenlist-1.3.3     | 40 KB     |            |   0%
# frozenlist-1.3.3     | 40 KB     | ###9       |  40%
# frozenlist-1.3.3     | 40 KB     | ########## | 100%
#
# gast-0.4.0           | 13 KB     |            |   0%
# gast-0.4.0           | 13 KB     | ########## | 100%
# gast-0.4.0           | 13 KB     | ########## | 100%
#
# oauthlib-3.2.2       | 209 KB    |            |   0%
# oauthlib-3.2.2       | 209 KB    | 7          |   8%
# oauthlib-3.2.2       | 209 KB    | ########## | 100%
# oauthlib-3.2.2       | 209 KB    | ########## | 100%
#
# absl-py-1.4.0        | 180 KB    |            |   0%
# absl-py-1.4.0        | 180 KB    | 8          |   9%
# absl-py-1.4.0        | 180 KB    | ########## | 100%
# absl-py-1.4.0        | 180 KB    | ########## | 100%
#
# yarl-1.8.1           | 80 KB     |            |   0%
# yarl-1.8.1           | 80 KB     | #9         |  20%
# yarl-1.8.1           | 80 KB     | ########## | 100%
#
# keras-applications-1 | 29 KB     |            |   0%
# keras-applications-1 | 29 KB     | #####5     |  56%
# keras-applications-1 | 29 KB     | ########## | 100%
#
# tensorflow-base-2.3. | 49.5 MB   |            |   0%
# tensorflow-base-2.3. | 49.5 MB   |            |   0%
# tensorflow-base-2.3. | 49.5 MB   |            |   0%
# tensorflow-base-2.3. | 49.5 MB   |            |   0%
# tensorflow-base-2.3. | 49.5 MB   |            |   1%
# tensorflow-base-2.3. | 49.5 MB   |            |   1%
# tensorflow-base-2.3. | 49.5 MB   | 1          |   1%
# tensorflow-base-2.3. | 49.5 MB   | 1          |   2%
# tensorflow-base-2.3. | 49.5 MB   | 2          |   2%
# tensorflow-base-2.3. | 49.5 MB   | 3          |   3%
# tensorflow-base-2.3. | 49.5 MB   | 4          |   4%
# tensorflow-base-2.3. | 49.5 MB   | 4          |   5%
# tensorflow-base-2.3. | 49.5 MB   | 5          |   6%
# tensorflow-base-2.3. | 49.5 MB   | 6          |   7%
# tensorflow-base-2.3. | 49.5 MB   | 7          |   7%
# tensorflow-base-2.3. | 49.5 MB   | 8          |   8%
# tensorflow-base-2.3. | 49.5 MB   | 9          |   9%
# tensorflow-base-2.3. | 49.5 MB   | 9          |  10%
# tensorflow-base-2.3. | 49.5 MB   | #          |  11%
# tensorflow-base-2.3. | 49.5 MB   | #1         |  12%
# tensorflow-base-2.3. | 49.5 MB   | #2         |  12%
# tensorflow-base-2.3. | 49.5 MB   | #3         |  13%
# tensorflow-base-2.3. | 49.5 MB   | #4         |  14%
# tensorflow-base-2.3. | 49.5 MB   | #5         |  15%
# tensorflow-base-2.3. | 49.5 MB   | #5         |  16%
# tensorflow-base-2.3. | 49.5 MB   | #6         |  17%
# tensorflow-base-2.3. | 49.5 MB   | #8         |  18%
# tensorflow-base-2.3. | 49.5 MB   | #9         |  19%
# tensorflow-base-2.3. | 49.5 MB   | ##         |  20%
# tensorflow-base-2.3. | 49.5 MB   | ##         |  21%
# tensorflow-base-2.3. | 49.5 MB   | ##1        |  22%
# tensorflow-base-2.3. | 49.5 MB   | ##2        |  22%
# tensorflow-base-2.3. | 49.5 MB   | ##3        |  23%
# tensorflow-base-2.3. | 49.5 MB   | ##4        |  24%
# tensorflow-base-2.3. | 49.5 MB   | ##4        |  25%
# tensorflow-base-2.3. | 49.5 MB   | ##5        |  26%
# tensorflow-base-2.3. | 49.5 MB   | ##6        |  26%
# tensorflow-base-2.3. | 49.5 MB   | ##7        |  27%
# tensorflow-base-2.3. | 49.5 MB   | ##8        |  28%
# tensorflow-base-2.3. | 49.5 MB   | ##8        |  29%
# tensorflow-base-2.3. | 49.5 MB   | ##9        |  30%
# tensorflow-base-2.3. | 49.5 MB   | ###        |  31%
# tensorflow-base-2.3. | 49.5 MB   | ###1       |  31%
# tensorflow-base-2.3. | 49.5 MB   | ###2       |  32%
# tensorflow-base-2.3. | 49.5 MB   | ###3       |  33%
# tensorflow-base-2.3. | 49.5 MB   | ###3       |  34%
# tensorflow-base-2.3. | 49.5 MB   | ###4       |  35%
# tensorflow-base-2.3. | 49.5 MB   | ###5       |  35%
# tensorflow-base-2.3. | 49.5 MB   | ###6       |  36%
# tensorflow-base-2.3. | 49.5 MB   | ###6       |  37%
# tensorflow-base-2.3. | 49.5 MB   | ###7       |  38%
# tensorflow-base-2.3. | 49.5 MB   | ###8       |  38%
# tensorflow-base-2.3. | 49.5 MB   | ###9       |  39%
# tensorflow-base-2.3. | 49.5 MB   | ###9       |  40%
# tensorflow-base-2.3. | 49.5 MB   | ####       |  40%
# tensorflow-base-2.3. | 49.5 MB   | ####1      |  41%
# tensorflow-base-2.3. | 49.5 MB   | ####2      |  42%
# tensorflow-base-2.3. | 49.5 MB   | ####2      |  43%
# tensorflow-base-2.3. | 49.5 MB   | ####3      |  44%
# tensorflow-base-2.3. | 49.5 MB   | ####4      |  44%
# tensorflow-base-2.3. | 49.5 MB   | ####5      |  45%
# tensorflow-base-2.3. | 49.5 MB   | ####5      |  46%
# tensorflow-base-2.3. | 49.5 MB   | ####6      |  47%
# tensorflow-base-2.3. | 49.5 MB   | ####7      |  48%
# tensorflow-base-2.3. | 49.5 MB   | ####8      |  48%
# tensorflow-base-2.3. | 49.5 MB   | ####9      |  49%
# tensorflow-base-2.3. | 49.5 MB   | #####      |  50%
# tensorflow-base-2.3. | 49.5 MB   | #####      |  51%
# tensorflow-base-2.3. | 49.5 MB   | #####1     |  52%
# tensorflow-base-2.3. | 49.5 MB   | #####2     |  52%
# tensorflow-base-2.3. | 49.5 MB   | #####3     |  53%
# tensorflow-base-2.3. | 49.5 MB   | #####3     |  54%
# tensorflow-base-2.3. | 49.5 MB   | #####4     |  55%
# tensorflow-base-2.3. | 49.5 MB   | #####5     |  56%
# tensorflow-base-2.3. | 49.5 MB   | #####6     |  56%
# tensorflow-base-2.3. | 49.5 MB   | #####7     |  57%
# tensorflow-base-2.3. | 49.5 MB   | #####7     |  58%
# tensorflow-base-2.3. | 49.5 MB   | #####8     |  59%
# tensorflow-base-2.3. | 49.5 MB   | #####9     |  59%
# tensorflow-base-2.3. | 49.5 MB   | #####9     |  60%
# tensorflow-base-2.3. | 49.5 MB   | ######     |  60%
# tensorflow-base-2.3. | 49.5 MB   | ######     |  61%
# tensorflow-base-2.3. | 49.5 MB   | ######1    |  61%
# tensorflow-base-2.3. | 49.5 MB   | ######1    |  62%
# tensorflow-base-2.3. | 49.5 MB   | ######2    |  62%
# tensorflow-base-2.3. | 49.5 MB   | ######2    |  63%
# tensorflow-base-2.3. | 49.5 MB   | ######3    |  63%
# tensorflow-base-2.3. | 49.5 MB   | ######3    |  64%
# tensorflow-base-2.3. | 49.5 MB   | ######4    |  64%
# tensorflow-base-2.3. | 49.5 MB   | ######4    |  65%
# tensorflow-base-2.3. | 49.5 MB   | ######5    |  65%
# tensorflow-base-2.3. | 49.5 MB   | ######5    |  66%
# tensorflow-base-2.3. | 49.5 MB   | ######6    |  66%
# tensorflow-base-2.3. | 49.5 MB   | ######6    |  67%
# tensorflow-base-2.3. | 49.5 MB   | ######7    |  67%
# tensorflow-base-2.3. | 49.5 MB   | ######7    |  68%
# tensorflow-base-2.3. | 49.5 MB   | ######8    |  68%
# tensorflow-base-2.3. | 49.5 MB   | ######8    |  69%
# tensorflow-base-2.3. | 49.5 MB   | ######9    |  69%
# tensorflow-base-2.3. | 49.5 MB   | ######9    |  70%
# tensorflow-base-2.3. | 49.5 MB   | #######    |  70%
# tensorflow-base-2.3. | 49.5 MB   | #######    |  71%
# tensorflow-base-2.3. | 49.5 MB   | #######1   |  71%
# tensorflow-base-2.3. | 49.5 MB   | #######1   |  72%
# tensorflow-base-2.3. | 49.5 MB   | #######2   |  72%
# tensorflow-base-2.3. | 49.5 MB   | #######2   |  73%
# tensorflow-base-2.3. | 49.5 MB   | #######3   |  73%
# tensorflow-base-2.3. | 49.5 MB   | #######3   |  74%
# tensorflow-base-2.3. | 49.5 MB   | #######4   |  74%
# tensorflow-base-2.3. | 49.5 MB   | #######4   |  75%
# tensorflow-base-2.3. | 49.5 MB   | #######5   |  75%
# tensorflow-base-2.3. | 49.5 MB   | #######5   |  76%
# tensorflow-base-2.3. | 49.5 MB   | #######6   |  76%
# tensorflow-base-2.3. | 49.5 MB   | #######6   |  77%
# tensorflow-base-2.3. | 49.5 MB   | #######7   |  77%
# tensorflow-base-2.3. | 49.5 MB   | #######7   |  78%
# tensorflow-base-2.3. | 49.5 MB   | #######8   |  78%
# tensorflow-base-2.3. | 49.5 MB   | #######8   |  79%
# tensorflow-base-2.3. | 49.5 MB   | #######9   |  79%
# tensorflow-base-2.3. | 49.5 MB   | #######9   |  80%
# tensorflow-base-2.3. | 49.5 MB   | ########   |  80%
# tensorflow-base-2.3. | 49.5 MB   | ########   |  81%
# tensorflow-base-2.3. | 49.5 MB   | ########1  |  81%
# tensorflow-base-2.3. | 49.5 MB   | ########1  |  82%
# tensorflow-base-2.3. | 49.5 MB   | ########2  |  82%
# tensorflow-base-2.3. | 49.5 MB   | ########2  |  83%
# tensorflow-base-2.3. | 49.5 MB   | ########3  |  83%
# tensorflow-base-2.3. | 49.5 MB   | ########4  |  84%
# tensorflow-base-2.3. | 49.5 MB   | ########5  |  85%
# tensorflow-base-2.3. | 49.5 MB   | ########5  |  86%
# tensorflow-base-2.3. | 49.5 MB   | ########6  |  86%
# tensorflow-base-2.3. | 49.5 MB   | ########6  |  87%
# tensorflow-base-2.3. | 49.5 MB   | ########7  |  88%
# tensorflow-base-2.3. | 49.5 MB   | ########8  |  89%
# tensorflow-base-2.3. | 49.5 MB   | ########9  |  89%
# tensorflow-base-2.3. | 49.5 MB   | #########  |  90%
# tensorflow-base-2.3. | 49.5 MB   | #########1 |  91%
# tensorflow-base-2.3. | 49.5 MB   | #########1 |  92%
# tensorflow-base-2.3. | 49.5 MB   | #########2 |  93%
# tensorflow-base-2.3. | 49.5 MB   | #########3 |  94%
# tensorflow-base-2.3. | 49.5 MB   | #########4 |  94%
# tensorflow-base-2.3. | 49.5 MB   | #########5 |  95%
# tensorflow-base-2.3. | 49.5 MB   | #########6 |  96%
# tensorflow-base-2.3. | 49.5 MB   | #########6 |  97%
# tensorflow-base-2.3. | 49.5 MB   | #########7 |  98%
# tensorflow-base-2.3. | 49.5 MB   | #########8 |  99%
# tensorflow-base-2.3. | 49.5 MB   | #########9 |  99%
# tensorflow-base-2.3. | 49.5 MB   | ########## | 100%
#
# mpc-1.1.0            | 260 KB    |            |   0%
# mpc-1.1.0            | 260 KB    | 6          |   6%
# mpc-1.1.0            | 260 KB    | ########## | 100%
# mpc-1.1.0            | 260 KB    | ########## | 100%
#
# libprotobuf-3.19.1   | 1.9 MB    |            |   0%
# libprotobuf-3.19.1   | 1.9 MB    |            |   1%
# libprotobuf-3.19.1   | 1.9 MB    | 3          |   3%
# libprotobuf-3.19.1   | 1.9 MB    | 6          |   6%
# libprotobuf-3.19.1   | 1.9 MB    | 9          |  10%
# libprotobuf-3.19.1   | 1.9 MB    | #4         |  15%
# libprotobuf-3.19.1   | 1.9 MB    | ##4        |  24%
# libprotobuf-3.19.1   | 1.9 MB    | ###2       |  32%
# libprotobuf-3.19.1   | 1.9 MB    | ####2      |  42%
# libprotobuf-3.19.1   | 1.9 MB    | #####8     |  58%
# libprotobuf-3.19.1   | 1.9 MB    | #######2   |  72%
# libprotobuf-3.19.1   | 1.9 MB    | ########   |  80%
# libprotobuf-3.19.1   | 1.9 MB    | ########## | 100%
# libprotobuf-3.19.1   | 1.9 MB    | ########## | 100%
#
# pyasn1-modules-0.2.8 | 72 KB     |            |   0%
# pyasn1-modules-0.2.8 | 72 KB     | ########## | 100%
# pyasn1-modules-0.2.8 | 72 KB     | ########## | 100%
#
# grpcio-1.42.0        | 1.9 MB    |            |   0%
# grpcio-1.42.0        | 1.9 MB    |            |   1%
# grpcio-1.42.0        | 1.9 MB    | 3          |   3%
# grpcio-1.42.0        | 1.9 MB    | 6          |   7%
# grpcio-1.42.0        | 1.9 MB    | #1         |  12%
# grpcio-1.42.0        | 1.9 MB    | #8         |  19%
# grpcio-1.42.0        | 1.9 MB    | ##5        |  25%
# grpcio-1.42.0        | 1.9 MB    | ###6       |  36%
# grpcio-1.42.0        | 1.9 MB    | ####7      |  47%
# grpcio-1.42.0        | 1.9 MB    | ######5    |  66%
# grpcio-1.42.0        | 1.9 MB    | ########5  |  86%
# grpcio-1.42.0        | 1.9 MB    | ########## | 100%
# grpcio-1.42.0        | 1.9 MB    | ########## | 100%
#
# requests-oauthlib-1. | 23 KB     |            |   0%
# requests-oauthlib-1. | 23 KB     | #######    |  70%
# requests-oauthlib-1. | 23 KB     | ########## | 100%
#
# tensorboard-2.10.0   | 5.6 MB    |            |   0%
# tensorboard-2.10.0   | 5.6 MB    |            |   0%
# tensorboard-2.10.0   | 5.6 MB    | 7          |   7%
# tensorboard-2.10.0   | 5.6 MB    | #5         |  15%
# tensorboard-2.10.0   | 5.6 MB    | ##2        |  23%
# tensorboard-2.10.0   | 5.6 MB    | ##9        |  30%
# tensorboard-2.10.0   | 5.6 MB    | ###7       |  37%
# tensorboard-2.10.0   | 5.6 MB    | ####4      |  45%
# tensorboard-2.10.0   | 5.6 MB    | #####2     |  52%
# tensorboard-2.10.0   | 5.6 MB    | #####9     |  60%
# tensorboard-2.10.0   | 5.6 MB    | ######6    |  67%
# tensorboard-2.10.0   | 5.6 MB    | #######4   |  74%
# tensorboard-2.10.0   | 5.6 MB    | ########1  |  82%
# tensorboard-2.10.0   | 5.6 MB    | ########7  |  88%
# tensorboard-2.10.0   | 5.6 MB    | #########3 |  94%
# tensorboard-2.10.0   | 5.6 MB    | #########9 | 100%
# tensorboard-2.10.0   | 5.6 MB    | ########## | 100%
#
# rsa-4.7.2            | 28 KB     |            |   0%
# rsa-4.7.2            | 28 KB     | ########## | 100%
# rsa-4.7.2            | 28 KB     | ########## | 100%
#
# _anaconda_depends-20 | 6 KB      |            |   0%
# _anaconda_depends-20 | 6 KB      | ########## | 100%
# _anaconda_depends-20 | 6 KB      | ########## | 100%
#
# openssl-1.1.1v       | 5.5 MB    |            |   0%
# openssl-1.1.1v       | 5.5 MB    |            |   1%
# openssl-1.1.1v       | 5.5 MB    | 4          |   4%
# openssl-1.1.1v       | 5.5 MB    | 9          |  10%
# openssl-1.1.1v       | 5.5 MB    | #7         |  17%
# openssl-1.1.1v       | 5.5 MB    | ##3        |  24%
# openssl-1.1.1v       | 5.5 MB    | ##8        |  28%
# openssl-1.1.1v       | 5.5 MB    | ###2       |  33%
# openssl-1.1.1v       | 5.5 MB    | ###6       |  37%
# openssl-1.1.1v       | 5.5 MB    | ####       |  41%
# openssl-1.1.1v       | 5.5 MB    | ####7      |  47%
# openssl-1.1.1v       | 5.5 MB    | #####1     |  52%
# openssl-1.1.1v       | 5.5 MB    | #####5     |  56%
# openssl-1.1.1v       | 5.5 MB    | ######     |  60%
# openssl-1.1.1v       | 5.5 MB    | ######5    |  66%
# openssl-1.1.1v       | 5.5 MB    | #######    |  70%
# openssl-1.1.1v       | 5.5 MB    | #######4   |  74%
# openssl-1.1.1v       | 5.5 MB    | #######7   |  78%
# openssl-1.1.1v       | 5.5 MB    | ########1  |  81%
# openssl-1.1.1v       | 5.5 MB    | ########5  |  85%
# openssl-1.1.1v       | 5.5 MB    | ########9  |  90%
# openssl-1.1.1v       | 5.5 MB    | #########3 |  94%
# openssl-1.1.1v       | 5.5 MB    | #########7 |  97%
# openssl-1.1.1v       | 5.5 MB    | ########## | 100%
#
# keras-preprocessing- | 35 KB     |            |   0%
# keras-preprocessing- | 35 KB     | ####5      |  46%
# keras-preprocessing- | 35 KB     | ########## | 100%
#
# blinker-1.4          | 23 KB     |            |   0%
# blinker-1.4          | 23 KB     | ######9    |  70%
# blinker-1.4          | 23 KB     | ########## | 100%
#
# Note: you may need to restart the kernel to use updated packages.
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/win-64::anaconda==2021.05=py38_0
#   - defaults/win-64::anaconda-client==1.7.2=py38_0
#   - defaults/win-64::anaconda-navigator==2.4.2=py38haa95532_0
#   - defaults/noarch::anaconda-project==0.9.1=pyhd3eb1b0_1
#   - defaults/win-64::astropy==4.2.1=py38h2bbff1b_1
#   - defaults/win-64::bkcharts==0.2=py38_0
#   - defaults/win-64::bokeh==2.3.2=py38haa95532_0
#   - defaults/win-64::bottleneck==1.3.2=py38h2a96729_1
#   - defaults/noarch::conda-repo-cli==1.0.4=pyhd3eb1b0_0
#   - defaults/noarch::dask==2021.4.0=pyhd3eb1b0_0
#   - defaults/noarch::flake8==3.9.0=pyhd3eb1b0_0
#   - defaults/win-64::h5py==2.10.0=py38h5e291fa_0
#   - defaults/win-64::imagecodecs==2021.3.31=py38h5da4933_0
#   - defaults/noarch::imageio==2.9.0=pyhd3eb1b0_0
#   - defaults/noarch::importlib_metadata==3.10.0=hd3eb1b0_0
#   - defaults/noarch::ipywidgets==7.6.3=pyhd3eb1b0_1
#   - defaults/noarch::jsonschema==3.2.0=py_2
#   - defaults/win-64::jupyter==1.0.0=py38_7
#   - defaults/noarch::jupyterlab==3.0.14=pyhd3eb1b0_1
#   - defaults/noarch::jupyterlab_server==2.4.0=pyhd3eb1b0_0
#   - defaults/win-64::jupyter_server==1.4.1=py38haa95532_0
#   - defaults/win-64::matplotlib==3.3.4=py38haa95532_0
#   - defaults/win-64::matplotlib-base==3.3.4=py38h49ac443_0
#   - defaults/win-64::mkl_fft==1.3.0=py38h277e83a_2
#   - defaults/win-64::mkl_random==1.2.1=py38hf11a4ad_2
#   - defaults/noarch::nbclassic==0.2.6=pyhd3eb1b0_0
#   - defaults/noarch::nbclient==0.5.3=pyhd3eb1b0_0
#   - defaults/win-64::nbconvert==6.0.7=py38_0
#   - defaults/noarch::nbformat==5.1.3=pyhd3eb1b0_0
#   - defaults/win-64::notebook==6.3.0=py38haa95532_0
#   - defaults/win-64::numba==0.53.1=py38hf11a4ad_0
#   - defaults/win-64::numexpr==2.7.3=py38hb80d3ca_1
#   - defaults/win-64::numpy==1.20.1=py38h34a8a5c_0
#   - defaults/win-64::pandas==1.2.4=py38hd77b12b_0
#   - defaults/win-64::patsy==0.5.1=py38_0
#   - defaults/win-64::pyerfa==1.7.3=py38h2bbff1b_0
#   - defaults/noarch::pyls-black==0.4.6=hd3eb1b0_0
#   - defaults/noarch::pyls-spyder==0.3.2=pyhd3eb1b0_0
#   - defaults/win-64::pytables==3.6.1=py38ha5be198_0
#   - defaults/noarch::python-language-server==0.36.2=pyhd3eb1b0_0
#   - defaults/win-64::pywavelets==1.1.1=py38he774522_2
#   - defaults/win-64::scikit-image==0.18.1=py38hf11a4ad_0
#   - defaults/win-64::scikit-learn==0.24.1=py38hf11a4ad_0
#   - defaults/win-64::scipy==1.6.2=py38h66253e8_1
#   - defaults/noarch::seaborn==0.11.1=pyhd3eb1b0_0
#   - defaults/win-64::spyder==4.2.5=py38haa95532_0
#   - defaults/win-64::statsmodels==0.12.2=py38h2bbff1b_0
#   - defaults/noarch::tifffile==2021.4.8=pyhd3eb1b0_2
#   - defaults/win-64::widgetsnbextension==3.5.1=py38_0
#   - defaults/win-64::_ipyw_jlab_nb_ext_conf==0.1.0=py38_0
#
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/win-64::anaconda==2021.05=py38_0
#   - defaults/win-64::anaconda-client==1.7.2=py38_0
#   - defaults/win-64::anaconda-navigator==2.4.2=py38haa95532_0
#   - defaults/noarch::anaconda-project==0.9.1=pyhd3eb1b0_1
#   - defaults/win-64::astropy==4.2.1=py38h2bbff1b_1
#   - defaults/win-64::bkcharts==0.2=py38_0
#   - defaults/win-64::bokeh==2.3.2=py38haa95532_0
#   - defaults/win-64::bottleneck==1.3.2=py38h2a96729_1
#   - defaults/noarch::conda-repo-cli==1.0.4=pyhd3eb1b0_0
#   - defaults/noarch::dask==2021.4.0=pyhd3eb1b0_0
#   - defaults/noarch::flake8==3.9.0=pyhd3eb1b0_0
#   - defaults/win-64::h5py==2.10.0=py38h5e291fa_0
#   - defaults/win-64::imagecodecs==2021.3.31=py38h5da4933_0
#   - defaults/noarch::imageio==2.9.0=pyhd3eb1b0_0
#   - defaults/noarch::importlib_metadata==3.10.0=hd3eb1b0_0
#   - defaults/noarch::ipywidgets==7.6.3=pyhd3eb1b0_1
#   - defaults/noarch::jsonschema==3.2.0=py_2
#   - defaults/win-64::jupyter==1.0.0=py38_7
#   - defaults/noarch::jupyterlab==3.0.14=pyhd3eb1b0_1
#   - defaults/noarch::jupyterlab_server==2.4.0=pyhd3eb1b0_0
#   - defaults/win-64::jupyter_server==1.4.1=py38haa95532_0
#   - defaults/win-64::matplotlib==3.3.4=py38haa95532_0
#   - defaults/win-64::matplotlib-base==3.3.4=py38h49ac443_0
#   - defaults/win-64::mkl_fft==1.3.0=py38h277e83a_2
#   - defaults/win-64::mkl_random==1.2.1=py38hf11a4ad_2
#   - defaults/noarch::nbclassic==0.2.6=pyhd3eb1b0_0
#   - defaults/noarch::nbclient==0.5.3=pyhd3eb1b0_0
#   - defaults/win-64::nbconvert==6.0.7=py38_0
#   - defaults/noarch::nbformat==5.1.3=pyhd3eb1b0_0
#   - defaults/win-64::notebook==6.3.0=py38haa95532_0
#   - defaults/win-64::numba==0.53.1=py38hf11a4ad_0
#   - defaults/win-64::numexpr==2.7.3=py38hb80d3ca_1
#   - defaults/win-64::numpy==1.20.1=py38h34a8a5c_0
#   - defaults/win-64::pandas==1.2.4=py38hd77b12b_0
#   - defaults/win-64::patsy==0.5.1=py38_0
#   - defaults/win-64::pyerfa==1.7.3=py38h2bbff1b_0
#   - defaults/noarch::pyls-black==0.4.6=hd3eb1b0_0
#   - defaults/noarch::pyls-spyder==0.3.2=pyhd3eb1b0_0
#   - defaults/win-64::pytables==3.6.1=py38ha5be198_0
#   - defaults/noarch::python-language-server==0.36.2=pyhd3eb1b0_0
#   - defaults/win-64::pywavelets==1.1.1=py38he774522_2
#   - defaults/win-64::scikit-image==0.18.1=py38hf11a4ad_0
#   - defaults/win-64::scikit-learn==0.24.1=py38hf11a4ad_0
#   - defaults/win-64::scipy==1.6.2=py38h66253e8_1
#   - defaults/noarch::seaborn==0.11.1=pyhd3eb1b0_0
#   - defaults/win-64::spyder==4.2.5=py38haa95532_0
#   - defaults/win-64::statsmodels==0.12.2=py38h2bbff1b_0
#   - defaults/noarch::tifffile==2021.4.8=pyhd3eb1b0_2
#   - defaults/win-64::widgetsnbextension==3.5.1=py38_0
#   - defaults/win-64::_ipyw_jlab_nb_ext_conf==0.1.0=py38_0
# tensorflow-2.3.0     | 6 KB      |            |   0%
# tensorflow-2.3.0     | 6 KB      | ########## | 100%
# tensorflow-2.3.0     | 6 KB      | ########## | 100%
#
# cachetools-4.2.2     | 13 KB     |            |   0%
# cachetools-4.2.2     | 13 KB     | ########## | 100%
# cachetools-4.2.2     | 13 KB     | ########## | 100%
#
# anaconda-custom      | 13 KB     |            |   0%
# anaconda-custom      | 13 KB     | ########## | 100%
# anaconda-custom      | 13 KB     | ########## | 100%
#
# certifi-2023.7.22    | 154 KB    |            |   0%
# certifi-2023.7.22    | 154 KB    | #          |  10%
# certifi-2023.7.22    | 154 KB    | ########## | 100%
# certifi-2023.7.22    | 154 KB    | ########## | 100%
#
# tensorboard-plugin-w | 671 KB    |            |   0%
# tensorboard-plugin-w | 671 KB    | 2          |   2%
# tensorboard-plugin-w | 671 KB    | ###        |  31%
# tensorboard-plugin-w | 671 KB    | #####7     |  57%
# tensorboard-plugin-w | 671 KB    | ########5  |  86%
# tensorboard-plugin-w | 671 KB    | ########## | 100%
#
# async-timeout-4.0.2  | 12 KB     |            |   0%
# async-timeout-4.0.2  | 12 KB     | ########## | 100%
# async-timeout-4.0.2  | 12 KB     | ########## | 100%
#
# termcolor-2.1.0      | 12 KB     |            |   0%
# termcolor-2.1.0      | 12 KB     | ########## | 100%
# termcolor-2.1.0      | 12 KB     | ########## | 100%
#
# multidict-6.0.2      | 46 KB     |            |   0%
# multidict-6.0.2      | 46 KB     | ###5       |  35%
# multidict-6.0.2      | 46 KB     | ########## | 100%
#
# pathtools-0.1.2      | 9 KB      |            |   0%
# pathtools-0.1.2      | 9 KB      | ########## | 100%
# pathtools-0.1.2      | 9 KB      | ########## | 100%
#
# mpir-3.0.0           | 1.3 MB    |            |   0%
# mpir-3.0.0           | 1.3 MB    | 1          |   1%
# mpir-3.0.0           | 1.3 MB    | 7          |   7%
# mpir-3.0.0           | 1.3 MB    | #4         |  14%
# mpir-3.0.0           | 1.3 MB    | ##1        |  22%
# mpir-3.0.0           | 1.3 MB    | ###1       |  31%
# mpir-3.0.0           | 1.3 MB    | ####7      |  47%
# mpir-3.0.0           | 1.3 MB    | ######5    |  65%
# mpir-3.0.0           | 1.3 MB    | #######9   |  80%
# mpir-3.0.0           | 1.3 MB    | ########## | 100%
# mpir-3.0.0           | 1.3 MB    | ########## | 100%
#
# libllvm9-9.0.1       | 61 KB     |            |   0%
# libllvm9-9.0.1       | 61 KB     | ##6        |  26%
# libllvm9-9.0.1       | 61 KB     | ########## | 100%
#
# aiohttp-3.8.3        | 416 KB    |            |   0%
# aiohttp-3.8.3        | 416 KB    | 3          |   4%
# aiohttp-3.8.3        | 416 KB    | #5         |  15%
# aiohttp-3.8.3        | 416 KB    | ###        |  31%
# aiohttp-3.8.3        | 416 KB    | ####6      |  46%
# aiohttp-3.8.3        | 416 KB    | #####7     |  58%
# aiohttp-3.8.3        | 416 KB    | ########## | 100%
# aiohttp-3.8.3        | 416 KB    | ########## | 100%
#
# aiosignal-1.2.0      | 12 KB     |            |   0%
# aiosignal-1.2.0      | 12 KB     | ########## | 100%
# aiosignal-1.2.0      | 12 KB     | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done

# %%
import tensorflow as tf

# %%
a = tf.constant(2)
b = tf.constant(3)

c = tf.add(a, b)

print(c)
# Out:
# tf.Tensor(5, shape=(), dtype=int32)

# %%
conda install -c conda-forge numpy=1.19.5
# Out:
# ^C
#
# Note: you may need to restart the kernel to use updated packages.

# %%
pip show numpy
# Out:
# Name: numpy
# Version: 1.20.1
# Summary: NumPy is the fundamental package for array computing with Python.
# Home-page: https://www.numpy.org
# Author: Travis E. Oliphant et al.
# Author-email: None
# License: BSD
# Location: c:\users\home\anaconda3\lib\site-packages
# Requires:
# Required-by: tifffile, tensorflow, tensorflow-intel, tensorboard, tables, statsmodels, seaborn, scipy, scikit-learn, scikit-image, PyWavelets, pyerfa, patsy, pandas, opt-einsum, numexpr, numba, mkl-random, mkl-fft, matplotlib, Keras-Preprocessing, Keras-Applications, imageio, imagecodecs, h5py, Bottleneck, bokeh, bkcharts, astropy
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy
numpy.__version__
# Out:
# '1.19.5'
