# %% [markdown]
# # People Retrieval Creation
#
# ### The following file is responsible for getting each player's individual stats and to set an average player as well in case we cannot find that player

# %% [markdown]
# We will start by importing the necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('classic')
import json

# %% [markdown]
# We will get the raw data that I have stored from my previous projects from two csv files.
#
# I have also displayed them here

# %%
bowlingStats = pd.read_csv("Resources/playerData/rawdata/bowling.csv")
battingStats = pd.read_csv("Resources/playerData/rawdata/batting.csv")
bowlingStats
# Out:
#                  Player  Country       Span  Mat Inns  Overs Mdns  Runs Wkts  \
# 0       Shakib Al Hasan      BAN  2006-2023  117  115  422.3    3  2869  140
# 1            TG Southee       NZ  2008-2022  107  105  389.1    3  3179  134
# 2           Rashid Khan  AFG/ICC  2015-2023   82   82  312.2    1  1925  130
# 3              IS Sodhi       NZ  2014-2023   98   95  339.1    0  2701  118
# 4            SL Malinga       SL  2006-2020   84   83  299.5    1  2225  107
# ...                 ...      ...        ...  ...  ...    ...  ...   ...  ...
# 3487   Zubaidi Zulkifle      MAL  2019-2023   36    -      -    -     -    -
# 3488        B Zuiderent      NED  2009-2010    6    -      -    -     -    -
# 3489  Zulfiqar Ali Shah     PORT  2021-2021    1    -      -    -     -    -
# 3490  Zulqarnain Haider      PAK  2007-2010    3    -      -    -     -    -
# 3491             L Zulu  SWA/SWZ  2021-2022    6    -      -    -     -    -
#
#        BBI    Ave  Econ    SR  4  5
# ...

# %%
battingStats
# Out:
#             Player Country       Span  Mat Inns  NO  Runs    HS    Ave    BF  \
# 0          V Kohli     IND  2010-2022  115  107  31  4008  122*  52.73  2905
# 1        RG Sharma     IND  2007-2022  148  140  17  3853   118  31.32  2767
# 2       MJ Guptill      NZ  2009-2022  122  118   7  3531   105  31.81  2602
# 3       Babar Azam     PAK  2016-2023  104   98  14  3485   122  41.48  2714
# 4      PR Stirling     IRE  2009-2023  129  128  11  3397  115*  29.03  2494
# ...            ...     ...        ...  ...  ...  ..   ...   ...    ...   ...
# 3487      S Zargar     Mex  2019-2019    1    -   -     -     -      -     -
# 3488   Zeshan Arif     Aut  2019-2019    3    -   -     -     -      -     -
# 3489  Ziaur Rahman     AFG  2019-2019    1    -   -     -     -      -     -
# 3490   Zoheb Malek     MLT  2021-2021    1    -   -     -     -      -     -
# 3491       Zou Kui     CHN  2023-2023    1    -   -     -     -      -     -
#
#           SR 100  50   0   4s   6s
# ...

# %% [markdown]
# #### We will start by replacing the "-" in each dataframe with np.NaN in order to make sure easy computations
#
# For battingStats, we will also remove the * at the end of each high scores in order to make sure we can convert it to integers.

# %%
bowlingStats.replace('-', np.NaN, inplace = True)
battingStats.replace("-", np.NaN, inplace = True)
battingStats['HS'] = battingStats['HS'].str.rstrip("*")

# %% [markdown]
# Next we will be setting the index of each of these players accordingly and naming the index as well.

# %%
bowlingStats.index.names = ['S. no']
battingStats.index.names = ['S. no']

# %% [markdown]
# #### We are going to add the average for battingStats and bowlingStats now.

# %%
battingStats.loc[3492, 'Player'] = 'Average'
bowlingStats.loc[3492, 'Player'] = 'Average'

# %% [markdown]
# Starting with bowling stats

# %%
numeric_cols = ['Mat', 'Inns', 'Overs', 'Mdns', 'Runs', 'Wkts', 'Ave', 'Econ', 'SR', '4', '5']
bowlingStats[numeric_cols] = bowlingStats[numeric_cols].apply(pd.to_numeric, errors='coerce')
column_means = bowlingStats.mean()
bowlingStats.fillna(column_means, inplace = True)
bowlingStats
# Out:
#                   Player  Country       Span         Mat        Inns  \
# S. no
# 0        Shakib Al Hasan      BAN  2006-2023  117.000000  115.000000
# 1             TG Southee       NZ  2008-2022  107.000000  105.000000
# 2            Rashid Khan  AFG/ICC  2015-2023   82.000000   82.000000
# 3               IS Sodhi       NZ  2014-2023   98.000000   95.000000
# 4             SL Malinga       SL  2006-2020   84.000000   83.000000
# ...                  ...      ...        ...         ...         ...
# 3488         B Zuiderent      NED  2009-2010    6.000000   10.710079
# 3489   Zulfiqar Ali Shah     PORT  2021-2021    1.000000   10.710079
# 3490   Zulqarnain Haider      PAK  2007-2010    3.000000   10.710079
# 3491              L Zulu  SWA/SWZ  2021-2022    6.000000   10.710079
# 3492             Average      NaN        NaN   13.805842   10.710079
#
#             Overs      Mdns         Runs        Wkts   BBI        Ave  \
# S. no
# ...

# %% [markdown]
# Doing the same for the batting stats

# %%
numeric_cols = ['Mat', "Inns", "NO", "Runs", "HS", "Ave", "BF", "SR", "100", "50", "0", "4s", "6s"]
battingStats[numeric_cols] = battingStats[numeric_cols].apply(pd.to_numeric, errors='coerce')
mean_col = battingStats.mean()
battingStats = battingStats.fillna(mean_col)
battingStats
# Out:
#              Player Country       Span         Mat        Inns         NO  \
# S. no
# 0           V Kohli     IND  2010-2022  115.000000  107.000000  31.000000
# 1         RG Sharma     IND  2007-2022  148.000000  140.000000  17.000000
# 2        MJ Guptill      NZ  2009-2022  122.000000  118.000000   7.000000
# 3        Babar Azam     PAK  2016-2023  104.000000   98.000000  14.000000
# 4       PR Stirling     IRE  2009-2023  129.000000  128.000000  11.000000
# ...             ...     ...        ...         ...         ...        ...
# 3488    Zeshan Arif     Aut  2019-2019    3.000000   10.844547   2.311214
# 3489   Ziaur Rahman     AFG  2019-2019    1.000000   10.844547   2.311214
# 3490    Zoheb Malek     MLT  2021-2021    1.000000   10.844547   2.311214
# 3491        Zou Kui     CHN  2023-2023    1.000000   10.844547   2.311214
# 3492        Average     NaN        NaN   13.805842   10.844547   2.311214
#
# ...

# %% [markdown]
# ## We are finally all done and it's time to store it! To access it later, use the following commands:
#
# ```py
#     bowlingStats = pd.read_pickle(r"Resources/playerData/bowling.pkl")
#     battingStats = pd.read_pickle(r"Resources/playerData/batting.pkl")
# ```

# %%
bowlingStats.to_pickle(r"Resources/playerData/bowling.pkl")
battingStats.to_pickle(r"Resources/playerData/batting.pkl")

# %%
bowlingStats
# Out:
#                   Player  Country       Span         Mat        Inns  \
# S. no
# 0        Shakib Al Hasan      BAN  2006-2023  117.000000  115.000000
# 1             TG Southee       NZ  2008-2022  107.000000  105.000000
# 2            Rashid Khan  AFG/ICC  2015-2023   82.000000   82.000000
# 3               IS Sodhi       NZ  2014-2023   98.000000   95.000000
# 4             SL Malinga       SL  2006-2020   84.000000   83.000000
# ...                  ...      ...        ...         ...         ...
# 3488         B Zuiderent      NED  2009-2010    6.000000   10.710079
# 3489   Zulfiqar Ali Shah     PORT  2021-2021    1.000000   10.710079
# 3490   Zulqarnain Haider      PAK  2007-2010    3.000000   10.710079
# 3491              L Zulu  SWA/SWZ  2021-2022    6.000000   10.710079
# 3492             Average      NaN        NaN   13.805842   10.710079
#
#             Overs      Mdns         Runs        Wkts   BBI        Ave  \
# S. no
# ...

# %%
battingStats
# Out:
#              Player Country       Span         Mat        Inns         NO  \
# S. no
# 0           V Kohli     IND  2010-2022  115.000000  107.000000  31.000000
# 1         RG Sharma     IND  2007-2022  148.000000  140.000000  17.000000
# 2        MJ Guptill      NZ  2009-2022  122.000000  118.000000   7.000000
# 3        Babar Azam     PAK  2016-2023  104.000000   98.000000  14.000000
# 4       PR Stirling     IRE  2009-2023  129.000000  128.000000  11.000000
# ...             ...     ...        ...         ...         ...        ...
# 3488    Zeshan Arif     Aut  2019-2019    3.000000   10.844547   2.311214
# 3489   Ziaur Rahman     AFG  2019-2019    1.000000   10.844547   2.311214
# 3490    Zoheb Malek     MLT  2021-2021    1.000000   10.844547   2.311214
# 3491        Zou Kui     CHN  2023-2023    1.000000   10.844547   2.311214
# 3492        Average     NaN        NaN   13.805842   10.844547   2.311214
#
# ...

# %% [markdown]
#  ### The code below is old code and only for reference, <font color = 'red'>  DO NOT RUN IT! </font>

# %%
bowlingStats[numeric_cols] = bowlingStats[numeric_cols].apply(pd.to_numeric, errors='coerce')
bowlingStats
# Out:
#                   Player  Country       Span         Mat        Inns  \
# S. no
# 0        Shakib Al Hasan      BAN  2006-2023  117.000000  115.000000
# 1             TG Southee       NZ  2008-2022  107.000000  105.000000
# 2            Rashid Khan  AFG/ICC  2015-2023   82.000000   82.000000
# 3               IS Sodhi       NZ  2014-2023   98.000000   95.000000
# 4             SL Malinga       SL  2006-2020   84.000000   83.000000
# ...                  ...      ...        ...         ...         ...
# 3488         B Zuiderent      NED  2009-2010    6.000000   10.710079
# 3489   Zulfiqar Ali Shah     PORT  2021-2021    1.000000   10.710079
# 3490   Zulqarnain Haider      PAK  2007-2010    3.000000   10.710079
# 3491              L Zulu  SWA/SWZ  2021-2022    6.000000   10.710079
# 3492             Average      NaN        NaN   13.805842   10.710079
#
#             Overs      Mdns         Runs        Wkts  BBI        Ave  \
# S. no
# ...

# %%
# Out:
#                   Player  Country       Span    Mat   Inns  Overs  Mdns  \
# S. no
# 0        Shakib Al Hasan      BAN  2006-2023  117.0  115.0  422.3   3.0
# 1             TG Southee       NZ  2008-2022  107.0  105.0  389.1   3.0
# 2            Rashid Khan  AFG/ICC  2015-2023   82.0   82.0  312.2   1.0
# 3               IS Sodhi       NZ  2014-2023   98.0   95.0  339.1   0.0
# 4             SL Malinga       SL  2006-2020   84.0   83.0  299.5   1.0
# ...                  ...      ...        ...    ...    ...    ...   ...
# 3488         B Zuiderent      NED  2009-2010    6.0    NaN    NaN   NaN
# 3489   Zulfiqar Ali Shah     PORT  2021-2021    1.0    NaN    NaN   NaN
# 3490   Zulqarnain Haider      PAK  2007-2010    3.0    NaN    NaN   NaN
# 3491              L Zulu  SWA/SWZ  2021-2022    6.0    NaN    NaN   NaN
# 3492             Average      NaN        NaN    NaN    NaN    NaN   NaN
#
#          Runs   Wkts  BBI    Ave  Econ    SR    4    5
# S. no
# ...

# %%
column_means = bowlingStats.mean()
column_means

# %%
# Out:
# Mat       13.805842
# Inns      10.710079
# Overs     32.795811
# Mdns       0.453754
# Runs     241.972625
# Wkts      10.520946
# BBI             NaN
# Ave       28.038534
# Econ       8.036798
# SR        21.845601
# 4          0.200332
# 5          0.051431
# dtype: float64

# %%
bowlingStats.fillna(column_means, inplace = True)
bowlingStats

# %%
# Out:
#                   Player  Country       Span         Mat        Inns  \
# S. no
# 0        Shakib Al Hasan      BAN  2006-2023  117.000000  115.000000
# 1             TG Southee       NZ  2008-2022  107.000000  105.000000
# 2            Rashid Khan  AFG/ICC  2015-2023   82.000000   82.000000
# 3               IS Sodhi       NZ  2014-2023   98.000000   95.000000
# 4             SL Malinga       SL  2006-2020   84.000000   83.000000
# ...                  ...      ...        ...         ...         ...
# 3488         B Zuiderent      NED  2009-2010    6.000000   10.710079
# 3489   Zulfiqar Ali Shah     PORT  2021-2021    1.000000   10.710079
# 3490   Zulqarnain Haider      PAK  2007-2010    3.000000   10.710079
# 3491              L Zulu  SWA/SWZ  2021-2022    6.000000   10.710079
# 3492             Average      NaN        NaN   13.805842   10.710079
#
#             Overs      Mdns         Runs        Wkts  BBI        Ave  \
# S. no
# ...

# %%
bowlingStats.to_csv("playerData/bowling.csv")

# %%
pd.read_csv("playerData/bowling.csv")
# Out:
#       S. no             Player  Country       Span         Mat        Inns  \
# 0         0    Shakib Al Hasan      BAN  2006-2023  117.000000  115.000000
# 1         1         TG Southee       NZ  2008-2022  107.000000  105.000000
# 2         2        Rashid Khan  AFG/ICC  2015-2023   82.000000   82.000000
# 3         3           IS Sodhi       NZ  2014-2023   98.000000   95.000000
# 4         4         SL Malinga       SL  2006-2020   84.000000   83.000000
# ...     ...                ...      ...        ...         ...         ...
# 3488   3488        B Zuiderent      NED  2009-2010    6.000000   10.710079
# 3489   3489  Zulfiqar Ali Shah     PORT  2021-2021    1.000000   10.710079
# 3490   3490  Zulqarnain Haider      PAK  2007-2010    3.000000   10.710079
# 3491   3491             L Zulu  SWA/SWZ  2021-2022    6.000000   10.710079
# 3492   3492            Average      NaN        NaN   13.805842   10.710079
#
# ...

# %%
battingStats = pd.read_csv("playerData/batting.csv")
battingStats['HS'] = battingStats['HS'].str.rstrip("*")
battingStats
# Out:
#             Player Country       Span  Mat Inns  NO  Runs   HS    Ave    BF  \
# 0          V Kohli     IND  2010-2022  115  107  31  4008  122  52.73  2905
# 1        RG Sharma     IND  2007-2022  148  140  17  3853  118  31.32  2767
# 2       MJ Guptill      NZ  2009-2022  122  118   7  3531  105  31.81  2602
# 3       Babar Azam     PAK  2016-2023  104   98  14  3485  122  41.48  2714
# 4      PR Stirling     IRE  2009-2023  129  128  11  3397  115  29.03  2494
# ...            ...     ...        ...  ...  ...  ..   ...  ...    ...   ...
# 3487      S Zargar     Mex  2019-2019    1    -   -     -    -      -     -
# 3488   Zeshan Arif     Aut  2019-2019    3    -   -     -    -      -     -
# 3489  Ziaur Rahman     AFG  2019-2019    1    -   -     -    -      -     -
# 3490   Zoheb Malek     MLT  2021-2021    1    -   -     -    -      -     -
# 3491       Zou Kui     CHN  2023-2023    1    -   -     -    -      -     -
#
#           SR 100  50   0   4s   6s
# ...

# %%
numeric_cols = ['Mat', "Inns", "NO", "Runs", "HS", "Ave", "BF", "SR", "100", "50", "0", "4s", "6s"]
battingStats[numeric_cols]
# Out:
#       Mat Inns  NO  Runs   HS    Ave    BF      SR 100  50   0   4s   6s
# 0     115  107  31  4008  122  52.73  2905  137.96   1  37   4  356  117
# 1     148  140  17  3853  118  31.32  2767  139.24   4  29  10  348  182
# 2     122  118   7  3531  105  31.81  2602  135.70   2  20   3  309  173
# 3     104   98  14  3485  122  41.48  2714  128.40   3  30   5  371   53
# 4     129  128  11  3397  115  29.03  2494  136.20   1  23  12  393  123
# ...   ...  ...  ..   ...  ...    ...   ...     ...  ..  ..  ..  ...  ...
# 3487    1    -   -     -    -      -     -       -   -   -   -    -    -
# 3488    3    -   -     -    -      -     -       -   -   -   -    -    -
# 3489    1    -   -     -    -      -     -       -   -   -   -    -    -
# 3490    1    -   -     -    -      -     -       -   -   -   -    -    -
# 3491    1    -   -     -    -      -     -       -   -   -   -    -    -
#
# [3492 rows x 13 columns]

# %%
battingStats[numeric_cols] = battingStats[numeric_cols].apply(pd.to_numeric, errors='coerce')
battingStats
# Out:
#             Player Country       Span  Mat   Inns    NO    Runs     HS    Ave  \
# 0          V Kohli     IND  2010-2022  115  107.0  31.0  4008.0  122.0  52.73
# 1        RG Sharma     IND  2007-2022  148  140.0  17.0  3853.0  118.0  31.32
# 2       MJ Guptill      NZ  2009-2022  122  118.0   7.0  3531.0  105.0  31.81
# 3       Babar Azam     PAK  2016-2023  104   98.0  14.0  3485.0  122.0  41.48
# 4      PR Stirling     IRE  2009-2023  129  128.0  11.0  3397.0  115.0  29.03
# ...            ...     ...        ...  ...    ...   ...     ...    ...    ...
# 3487      S Zargar     Mex  2019-2019    1    NaN   NaN     NaN    NaN    NaN
# 3488   Zeshan Arif     Aut  2019-2019    3    NaN   NaN     NaN    NaN    NaN
# 3489  Ziaur Rahman     AFG  2019-2019    1    NaN   NaN     NaN    NaN    NaN
# 3490   Zoheb Malek     MLT  2021-2021    1    NaN   NaN     NaN    NaN    NaN
# 3491       Zou Kui     CHN  2023-2023    1    NaN   NaN     NaN    NaN    NaN
#
# ...

# %%
battingStats.index.names = ["S. no"]
battingStats
# Out:
#              Player Country       Span  Mat   Inns    NO    Runs     HS  \
# S. no
# 0           V Kohli     IND  2010-2022  115  107.0  31.0  4008.0  122.0
# 1         RG Sharma     IND  2007-2022  148  140.0  17.0  3853.0  118.0
# 2        MJ Guptill      NZ  2009-2022  122  118.0   7.0  3531.0  105.0
# 3        Babar Azam     PAK  2016-2023  104   98.0  14.0  3485.0  122.0
# 4       PR Stirling     IRE  2009-2023  129  128.0  11.0  3397.0  115.0
# ...             ...     ...        ...  ...    ...   ...     ...    ...
# 3487       S Zargar     Mex  2019-2019    1    NaN   NaN     NaN    NaN
# 3488    Zeshan Arif     Aut  2019-2019    3    NaN   NaN     NaN    NaN
# 3489   Ziaur Rahman     AFG  2019-2019    1    NaN   NaN     NaN    NaN
# 3490    Zoheb Malek     MLT  2021-2021    1    NaN   NaN     NaN    NaN
# 3491        Zou Kui     CHN  2023-2023    1    NaN   NaN     NaN    NaN
#
#          Ave      BF      SR  100    50     0     4s     6s
# S. no
# ...

# %%
battingStats.loc[725, "Player"] = "Average"
mean_col = battingStats.mean()
battingStats = battingStats.fillna(mean_col)
battingStats
# Out:
#              Player Country       Span  Mat        Inns         NO    Runs  \
# S. no
# 0           V Kohli     IND  2010-2022  115  107.000000  31.000000  4008.0
# 1         RG Sharma     IND  2007-2022  148  140.000000  17.000000  3853.0
# 2        MJ Guptill      NZ  2009-2022  122  118.000000   7.000000  3531.0
# 3        Babar Azam     PAK  2016-2023  104   98.000000  14.000000  3485.0
# 4       PR Stirling     IRE  2009-2023  129  128.000000  11.000000  3397.0
# ...             ...     ...        ...  ...         ...        ...     ...
# 3487       S Zargar     Mex  2019-2019    1   10.844547   2.311214   171.6
# 3488    Zeshan Arif     Aut  2019-2019    3   10.844547   2.311214   171.6
# 3489   Ziaur Rahman     AFG  2019-2019    1   10.844547   2.311214   171.6
# 3490    Zoheb Malek     MLT  2021-2021    1   10.844547   2.311214   171.6
# 3491        Zou Kui     CHN  2023-2023    1   10.844547   2.311214   171.6
#
# ...

# %%
bowlingStats
# Out:
#                   Player  Country       Span         Mat        Inns  \
# S. no
# 0        Shakib Al Hasan      BAN  2006-2023  117.000000  115.000000
# 1             TG Southee       NZ  2008-2022  107.000000  105.000000
# 2            Rashid Khan  AFG/ICC  2015-2023   82.000000   82.000000
# 3               IS Sodhi       NZ  2014-2023   98.000000   95.000000
# 4             SL Malinga       SL  2006-2020   84.000000   83.000000
# ...                  ...      ...        ...         ...         ...
# 3488         B Zuiderent      NED  2009-2010    6.000000   10.710079
# 3489   Zulfiqar Ali Shah     PORT  2021-2021    1.000000   10.710079
# 3490   Zulqarnain Haider      PAK  2007-2010    3.000000   10.710079
# 3491              L Zulu  SWA/SWZ  2021-2022    6.000000   10.710079
# 3492             Average      NaN        NaN   13.805842   10.710079
#
#             Overs      Mdns         Runs        Wkts  BBI        Ave  \
# S. no
# ...

# %%
battingStats.to_csv("playerData/batting.csv")
bowlingStats.to_csv("playerData/bowling.csv")
