# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('classic')
import json

# %%
all_innings = pd.read_csv("match_data.csv")
# Out:
# C:\Users\HOME\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (15,16) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
all_innings
# Out:
#         Unnamed: 0   Unnamed: 1  Unnamed: 2  Unnamed: 3            batter  \
# 0          1381452      Austria           0           0  M Simpson-Parker
# 1          1381452      Austria           0           1  M Simpson-Parker
# 2          1381452      Austria           0           2  M Simpson-Parker
# 3          1381452      Austria           0           3  M Simpson-Parker
# 4          1381452      Austria           0           4  M Simpson-Parker
# ...            ...          ...         ...         ...               ...
# 407784      211048  New Zealand          19           1         JW Wilson
# 407785      211048  New Zealand          19           2         JW Wilson
# 407786      211048  New Zealand          19           3         DR Tuffey
# 407787      211048  New Zealand          19           4         DR Tuffey
# 407788      211048  New Zealand          19           5          KD Mills
#
#                bowler    non_striker  batter runs  extra runs  total runs  \
# ...

# %%
all_innings = all_innings.set_index(["Unnamed: 0", "Unnamed: 1", "Unnamed: 2", "Unnamed: 3"])

# %%
all_innings.index.names = ["Match Code", "Country", "Over", "Ball"]

# %%
all_innings
# Out:
#                                             batter         bowler  \
# Match Code Country     Over Ball
# 1381452    Austria     0    0     M Simpson-Parker  Ghulam Ahmadi
#                             1     M Simpson-Parker  Ghulam Ahmadi
#                             2     M Simpson-Parker  Ghulam Ahmadi
#                             3     M Simpson-Parker  Ghulam Ahmadi
#                             4     M Simpson-Parker  Ghulam Ahmadi
# ...                                            ...            ...
# 211048     New Zealand 19   1            JW Wilson     GD McGrath
#                             2            JW Wilson     GD McGrath
#                             3            DR Tuffey     GD McGrath
#                             4            DR Tuffey     GD McGrath
#                             5             KD Mills     GD McGrath
#
#                                     non_striker  batter runs  extra runs  \
# Match Code Country     Over Ball
# ...

# %%
all_batters =     set(all_innings.loc[:, 'batter'])
all_batters = list(all_batters)
all_batters.sort()
"PP Ojha" in all_batters
print(len(all_batters))
# Out:
# 2785

# %%
batters = pd.read_csv("playerData/batting.csv")
batters.set_index("S. no", inplace = True)

# %%
len(batters)
# Out:
# 3492

# %%
batters
# Out:
#              Player Country       Span  Mat        Inns         NO    Runs  \
# S. no
# 0           V Kohli     IND  2010-2022  115  107.000000  31.000000  4008.0
# 1         RG Sharma     IND  2007-2022  148  140.000000  17.000000  3853.0
# 2        MJ Guptill      NZ  2009-2022  122  118.000000   7.000000  3531.0
# 3        Babar Azam     PAK  2016-2023  104   98.000000  14.000000  3485.0
# 4       PR Stirling     IRE  2009-2023  129  128.000000  11.000000  3397.0
# ...             ...     ...        ...  ...         ...        ...     ...
# 3487       S Zargar     Mex  2019-2019    1   10.844547   2.311214   171.6
# 3488    Zeshan Arif     Aut  2019-2019    3   10.844547   2.311214   171.6
# 3489   Ziaur Rahman     AFG  2019-2019    1   10.844547   2.311214   171.6
# 3490    Zoheb Malek     MLT  2021-2021    1   10.844547   2.311214   171.6
# 3491        Zou Kui     CHN  2023-2023    1   10.844547   2.311214   171.6
#
# ...

# %%
batters_name = batters.loc[:, "Player"]

# %%
x = 0
for each in list(batters_name):
    if each in all_batters:
        x += 1
print(x)
# Out:
# 2717

# %%
len(list(set(all_batters) - set(batters_name)))
# Out:
# 95
