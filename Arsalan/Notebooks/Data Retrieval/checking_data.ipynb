# %% [markdown]
# # Checking data
#
# ### Just checking data for random stuff

# %%
import numpy as np
import pandas as pd
from pathlib import Path
import random
current_dir = Path.cwd()
parent_dir = current_dir.parent.parent

# %%
ground_player_lineup = pd.read_pickle(parent_dir / "Resources/ground_player_lineup.pkl")
innings = pd.read_pickle(parent_dir / "Resources/match_data.pkl")
player_stats = pd.read_pickle(parent_dir / "Resources/MatchData/match_player_stats.pkl")
player_status = pd.read_pickle(parent_dir / "Resources/MatchData/player_status.pkl")

# %%
innings.loc[1359787]
# Out:
#                            batter        bowler   non_striker  batter runs  \
# Country   Over Ball
# Bermuda   0    0      KS Leverock  A Kirschbaum     T Manders            0
#                1      KS Leverock  A Kirschbaum     T Manders            0
#                2      KS Leverock  A Kirschbaum     T Manders            4
#                3      KS Leverock  A Kirschbaum     T Manders            1
#                4        T Manders  A Kirschbaum   KS Leverock            1
# ...                           ...           ...           ...          ...
# Argentina 19   1          D Mauro   DMW Rawlins  A Kirschbaum            0
#                2     A Kirschbaum   DMW Rawlins       D Mauro            2
#                3     A Kirschbaum   DMW Rawlins       D Mauro            0
#                4     A Kirschbaum   DMW Rawlins       D Mauro            0
#                5     A Kirschbaum   DMW Rawlins       D Mauro            0
#
#                      extra runs  total runs  score          extras  \
# Country   Over Ball
# Bermuda   0    0              0           0      0             NaN
#                1              0           0      0             NaN
#                2              0           4      4             NaN
#                3              0           1      5             NaN
#                4              0           1      6             NaN
# ...                         ...         ...    ...             ...
# Argentina 19   1              1           1    117  {'legbyes': 1}
#                2              0           2    119             NaN
#                3              0           0    119             NaN
#                4              0           0    119             NaN
#                5              0           0    119             NaN
#
#                           wickets  out  Total Wickets non_boundary review  \
# Country   Over Ball
# Bermuda   0    0              NaN    0              0          NaN    NaN
#                1              NaN    0              0          NaN    NaN
#                2              NaN    0              0          NaN    NaN
#                3              NaN    0              0          NaN    NaN
#                4              NaN    0              0          NaN    NaN
# ...                           ...  ...            ...          ...    ...
# Argentina 19   1              NaN    0              4          NaN    NaN
#                2              NaN    0              4          NaN    NaN
#                3              NaN    0              4          NaN    NaN
#                4              NaN    0              4          NaN    NaN
#                5     A Kirschbaum    1              5          NaN    NaN
#
#                     replacements
# Country   Over Ball
# Bermuda   0    0             NaN
#                1             NaN
#                2             NaN
#                3             NaN
#                4             NaN
# ...                          ...
# Argentina 19   1             NaN
#                2             NaN
#                3             NaN
#                4             NaN
#                5             NaN
#
# [250 rows x 14 columns]

# %%
ground_player_lineup = pd.read_pickle(parent_dir / "Resources/ground_player_lineup.pkl")

# %%
ground_player_lineup
# Out:
#                                            Details                \
#                                        Ground Name   Winner Name
# Match Code
# 1381452        Sportpark Het Schootsveld, Deventer       Germany
# 1381451        Sportpark Het Schootsveld, Deventer       Germany
# 1381456             National Sports Academy, Sofia        Turkey
# 1381457             National Sports Academy, Sofia        Serbia
# 1381458             National Sports Academy, Sofia      Bulgaria
# ...                                            ...           ...
# 225271                               The Rose Bowl     Sri Lanka
# 238195                       New Wanderers Stadium  South Africa
# 226374      Brisbane Cricket Ground, Woolloongabba     Australia
# 211028                               The Rose Bowl       England
# 211048                                   Eden Park     Australia
#
#                                             Batting Team                 \
#             Batting Team  Bowling Team                P1             P2
# Match Code
# 1381452          Austria       Germany  M Simpson-Parker  Iqbal Hossain
# 1381451          Austria       Germany  M Simpson-Parker  Iqbal Hossain
# 1381456          Croatia        Turkey          WK Bitis    Naseem Khan
# 1381457          Croatia        Serbia          A Daxini    Naseem Khan
# 1381458           Turkey      Bulgaria    Ilyas Ataullah         I Elec
# ...                  ...           ...               ...            ...
# 225271         Sri Lanka       England     ST Jayasuriya    WU Tharanga
# 238195      South Africa     Australia          GC Smith      LE Bosman
# 226374         Australia  South Africa          JR Hopes      DR Martyn
# 211028           England     Australia    ME Trescothick       GO Jones
# 211048         Australia   New Zealand      AC Gilchrist      MJ Clarke
#
#                                                                                \
#                           P3            P4               P5                P6
# Match Code
# 1381452      Razmal Shigiwal    A Randhawa     Shahil Momin       Mirza Ahsan
# 1381451      Razmal Shigiwal    A Randhawa      Mirza Ahsan      Shahil Momin
# 1381456            P Bosnjak  Sohail Ahmad         A Daxini           V Zanko
# 1381457            P Bosnjak       V Zanko     A Magdalenic          WK Bitis
# 1381458            A Turkmen        R Nath         M Ozturk  Muhammed Turkmen
# ...                      ...           ...              ...               ...
# 225271      DPMD Jayawardene    TM Dilshan    KC Sangakkara         RP Arnold
# 238195              HH Gibbs    SM Pollock  JJ van der Wath    AB de Villiers
# 226374            RT Ponting     A Symonds        MJ Clarke        MEK Hussey
# 211028            A Flintoff  KP Pietersen       MP Vaughan    PD Collingwood
# 211048             A Symonds    RT Ponting        DR Martyn         SM Katich
#
#             ...    Bowling Team                                    \
#             ...              P2               P3               P4
# Match Code  ...
# 1381452     ...   J van Heerden    MJ Richardson  Faisal Mubashir
# 1381451     ...   J van Heerden  VB Chikkannaiah  Faisal Mubashir
# 1381456     ...  Ilyas Ataullah        A Turkmen           R Nath
# 1381457     ...        A Dizija        LA Dunbar      MV Pavlovic
# 1381458     ...       Zain Asif      Zaid Soulat         P Mishra
# ...         ...             ...              ...              ...
# 225271      ...      AJ Strauss     KP Pietersen   PD Collingwood
# 238195      ...       SM Katich       RT Ponting        DR Martyn
# 226374      ...    HH Dippenaar         HH Gibbs       MV Boucher
# 211028      ...       ML Hayden        A Symonds        MJ Clarke
# 211048      ...      SP Fleming      MS Sinclair        SB Styris
#
#                                                                              \
#                           P5           P6             P7                 P8
# Match Code
# 1381452        Ghulam Ahmadi   Muslim Yar   SVE Bharathi       Abdul Bashir
# 1381451         Sahir Naqash  DA Blignaut  Ghulam Ahmadi       Sachin Mandy
# 1381456     Muhammed Turkmen     M Ozturk    Cihan Altun     Muhammet Bicer
# 1381457              S Tosic   V Zimonjic     N Zimonjic  NR Johns-Wickberg
# 1381458            Isa Zaroo    D Nikolov    Danyal Raja         A Ahmadhel
# ...                      ...          ...            ...                ...
# 225271         JWM Dalrymple     GO Jones     TT Bresnan           EC Joyce
# 238195             MJ Clarke    SR Watson        GB Hogg              B Lee
# 226374            SM Pollock    JH Kallis     JA Rudolph            AJ Hall
# 211028            MEK Hussey   RT Ponting      DR Martyn              B Lee
# 211048           CD McMillan    CL Cairns   HJH Marshall           AR Adams
#
#
#                          P9            P10            P11
# Match Code
# 1381452        Sachin Mandy   Sahir Naqash        H Singh
# 1381451        SVE Bharathi     Muslim Yar        D Klein
# 1381456     Muhammet Kursat     Murat Ipek   Murat Yilmaz
# 1381457        Rahman Ademi       AA Gajic      M Sarenac
# 1381458     Gagandeep Singh    DV Varghese  Huzaif Yousuf
# ...                     ...            ...            ...
# 225271          LE Plunkett     SI Mahmood    SJ Harmison
# 238195           NW Bracken       ML Lewis       SR Clark
# 226374              J Botha     GJP Kruger      M Zondeki
# 211028         JN Gillespie  MS Kasprowicz     GD McGrath
# 211048            JW Wilson       KD Mills      DR Tuffey
#
# [1769 rows x 26 columns]
